# %%
from google.colab import drive
import os

# 1. 드라이브 마운트
drive.mount('/content/drive')

# 2. 압축 해제 (dataset 폴더로 해제)
zip_path = '/content/drive/MyDrive/n_seoul_tower_dataset3.zip'

# 현재 위치에 압축 해제
# !unzip -q "{zip_path}" -d /content/dataset
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 1. Ultralytics 설치
# !pip install ultralytics

from ultralytics import YOLO

# 2. 모델 로드 (가벼운 모델인 nano 버전)
model = YOLO('yolov8n.pt')

# 3. 학습 시작
# data.yaml 경로는 압축 푼 폴더 내부
# 보통 /content/dataset/data.yaml 에 위치함
results = model.train(
    data='/content/dataset/n_seoul_tower_dataset3/data.yaml',
    epochs=50,  # 학습 횟수
    imgsz=640,  # 이미지 크기
    batch=16,   # 배치 사이즈
    name='n_tower_model' # 결과 폴더 이름
)
# Out:
# ...
# Ultralytics 8.3.239 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
